# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
query_url = f"{base_url}appid={weather_api_key}&q="

# Initiate Count
record_number = 0
record_set = 1

# Set up lists to hold reponse info in dataframe
name_city = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

# Print Header
print(f"Beginning Data Retrieval")
print(f"-----------------------------------------")

# Loop through the list of cities
for city in cities:    
    
    # Create search query, make request and store in json with a 2 second timer for pausing to avoid temporarily blocking my OpenWeatherMap API key
    weather_response = requests.get(query_url + str(city))
    weather_response_json = weather_response.json()
    time.sleep(2)   
    
    # Try to retrieve and store weather conditions into lists and if a random city is not found in the Open Weathermap then skip 
    try:
        name_city.append(weather_response_json["name"])
        cloudiness.append(weather_response_json["clouds"]["all"])
        country.append(weather_response_json["sys"]["country"])
        date.append(weather_response_json["dt"])
        humidity.append(weather_response_json["main"]["humidity"])
        latitude.append(weather_response_json["coord"]["lat"])
        longitude.append(weather_response_json["coord"]["lon"])
        max_temp.append(weather_response_json["main"]["temp_max"])
        wind_speed.append(weather_response_json["wind"]["speed"])
                   
        print(f"Processing Record {record_number} of Set {record_set} | {city}")
        record_number += 1
        #print(f"Processing Record {record_number}")
        
    except:
        # Append null values
        print("City not found. Skipping...")

print(f"-----------------------------------------")
print(f"Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -----------------------------------------
# City not found. Skipping...
# Processing Record 0 of Set 1 | bulalacao
# Processing Record 1 of Set 1 | ahipara
# Processing Record 2 of Set 1 | codrington
# City not found. Skipping...
# Processing Record 3 of Set 1 | cockburn town
# Processing Record 4 of Set 1 | cam ranh
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | hof
# Processing Record 9 of Set 1 | itatiaia
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | bend
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | tual
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | ust-maya
# Processing Record 16 of Set 1 | roma
# Processing Record 17 of Set 1 | hasaki
# City not found. Skipping...
# Processing Record 18 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | hovd
# Processing Record 22 of Set 1 | dikson
# City not found. Skipping...
# Processing Record 23 of Set 1 | ornskoldsvik
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | port hardy
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | salalah
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | kon tum
# City not found. Skipping...
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | padang
# City not found. Skipping...
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | fortuna
# Processing Record 38 of Set 1 | sao felix do xingu
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | lerwick
# Processing Record 41 of Set 1 | nuuk
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | iringa
# Processing Record 44 of Set 1 | fort dodge
# Processing Record 45 of Set 1 | dmitriyevka
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | cooma
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | avarua
# Processing Record 51 of Set 1 | pavlovka
# Processing Record 52 of Set 1 | pacific grove
# City not found. Skipping...
# Processing Record 53 of Set 1 | punta arenas
# Processing Record 54 of Set 1 | kodiak
# Processing Record 55 of Set 1 | vaini
# Processing Record 56 of Set 1 | leningradskiy
# Processing Record 57 of Set 1 | kaitangata
# Processing Record 58 of Set 1 | nantucket
# Processing Record 59 of Set 1 | chokurdakh
# Processing Record 60 of Set 1 | tyup
# Processing Record 61 of Set 1 | yellowknife
# Processing Record 62 of Set 1 | berdigestyakh
# Processing Record 63 of Set 1 | amboise
# City not found. Skipping...
# Processing Record 64 of Set 1 | port elizabeth
# Processing Record 65 of Set 1 | los llanos de aridane
# Processing Record 66 of Set 1 | talnakh
# Processing Record 67 of Set 1 | zyryanka
# City not found. Skipping...
# Processing Record 68 of Set 1 | busselton
# Processing Record 69 of Set 1 | sorland
# Processing Record 70 of Set 1 | iqaluit
# Processing Record 71 of Set 1 | rudbar
# Processing Record 72 of Set 1 | bethel
# Processing Record 73 of Set 1 | dezhou
# Processing Record 74 of Set 1 | rikitea
# Processing Record 75 of Set 1 | zolotonosha
# City not found. Skipping...
# Processing Record 76 of Set 1 | lebu
# Processing Record 77 of Set 1 | hays
# Processing Record 78 of Set 1 | roros
# Processing Record 79 of Set 1 | ribeira grande
# Processing Record 80 of Set 1 | san carlos del zulia
# Processing Record 81 of Set 1 | beira
# Processing Record 82 of Set 1 | nemuro
# Processing Record 83 of Set 1 | new norfolk
# Processing Record 84 of Set 1 | isla vista
# Processing Record 85 of Set 1 | hermanus
# Processing Record 86 of Set 1 | snezhnogorsk
# Processing Record 87 of Set 1 | mar del plata
# Processing Record 88 of Set 1 | sur
# Processing Record 89 of Set 1 | norman wells
# City not found. Skipping...
# Processing Record 90 of Set 1 | isla mujeres
# Processing Record 91 of Set 1 | teguise
# Processing Record 92 of Set 1 | georgetown
# Processing Record 93 of Set 1 | hobyo
# Processing Record 94 of Set 1 | gwanda
# Processing Record 95 of Set 1 | harlingen
# City not found. Skipping...
# Processing Record 96 of Set 1 | buraydah
# Processing Record 97 of Set 1 | hongjiang
# Processing Record 98 of Set 1 | luderitz
# Processing Record 99 of Set 1 | san antonio
# Processing Record 100 of Set 1 | carnarvon
# Processing Record 101 of Set 1 | dakoro
# Processing Record 102 of Set 1 | hithadhoo
# Processing Record 103 of Set 1 | lavrentiya
# Processing Record 104 of Set 1 | sinnamary
# Processing Record 105 of Set 1 | kingsland
# City not found. Skipping...
# Processing Record 106 of Set 1 | gallup
# Processing Record 107 of Set 1 | bandarbeyla
# Processing Record 108 of Set 1 | bereda
# Processing Record 109 of Set 1 | kalemie
# Processing Record 110 of Set 1 | shelburne
# Processing Record 111 of Set 1 | beidao
# Processing Record 112 of Set 1 | jalu
# Processing Record 113 of Set 1 | amapa
# Processing Record 114 of Set 1 | koumac
# Processing Record 115 of Set 1 | camacha
# Processing Record 116 of Set 1 | baykit
# Processing Record 117 of Set 1 | cherskiy
# Processing Record 118 of Set 1 | upernavik
# Processing Record 119 of Set 1 | oksfjord
# City not found. Skipping...
# Processing Record 120 of Set 1 | nikolskoye
# Processing Record 121 of Set 1 | ilulissat
# Processing Record 122 of Set 1 | manuk mangkaw
# Processing Record 123 of Set 1 | saint-philippe
# Processing Record 124 of Set 1 | kyzyl-mazhalyk
# Processing Record 125 of Set 1 | jasper
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 126 of Set 1 | barrow
# Processing Record 127 of Set 1 | port alfred
# Processing Record 128 of Set 1 | gamba
# Processing Record 129 of Set 1 | vila velha
# Processing Record 130 of Set 1 | dwarka
# Processing Record 131 of Set 1 | harper
# Processing Record 132 of Set 1 | santo andre
# Processing Record 133 of Set 1 | faanui
# Processing Record 134 of Set 1 | bousso
# Processing Record 135 of Set 1 | bulgan
# Processing Record 136 of Set 1 | hobart
# Processing Record 137 of Set 1 | izumo
# Processing Record 138 of Set 1 | ballina
# Processing Record 139 of Set 1 | marfino
# Processing Record 140 of Set 1 | katsuura
# Processing Record 141 of Set 1 | san luis potosi
# Processing Record 142 of Set 1 | zenzeli
# Processing Record 143 of Set 1 | maralal
# City not found. Skipping...
# Processing Record 144 of Set 1 | puerto ayora
# Processing Record 145 of Set 1 | sitka
# Processing Record 146 of Set 1 | champerico
# Processing Record 147 of Set 1 | khor
# Processing Record 148 of Set 1 | kayes
# Processing Record 149 of Set 1 | marathon
# Processing Record 150 of Set 1 | berlevag
# Processing Record 151 of Set 1 | gorontalo
# City not found. Skipping...
# Processing Record 152 of Set 1 | basti
# Processing Record 153 of Set 1 | kununurra
# Processing Record 154 of Set 1 | tiksi
# Processing Record 155 of Set 1 | dalvik
# Processing Record 156 of Set 1 | beringovskiy
# Processing Record 157 of Set 1 | ponta do sol
# Processing Record 158 of Set 1 | clyde river
# Processing Record 159 of Set 1 | mount gambier
# Processing Record 160 of Set 1 | saint george
# Processing Record 161 of Set 1 | lalmohan
# Processing Record 162 of Set 1 | karpathos
# Processing Record 163 of Set 1 | annau
# Processing Record 164 of Set 1 | airai
# City not found. Skipping...
# Processing Record 165 of Set 1 | amahai
# Processing Record 166 of Set 1 | bambous virieux
# Processing Record 167 of Set 1 | nelson bay
# Processing Record 168 of Set 1 | port-gentil
# Processing Record 169 of Set 1 | kokoda
# Processing Record 170 of Set 1 | serta
# City not found. Skipping...
# Processing Record 171 of Set 1 | jamestown
# Processing Record 172 of Set 1 | cabo san lucas
# Processing Record 173 of Set 1 | gat
# Processing Record 174 of Set 1 | saint-augustin
# Processing Record 175 of Set 1 | putiao
# Processing Record 176 of Set 1 | sembakung
# Processing Record 177 of Set 1 | tukrah
# Processing Record 178 of Set 1 | constitucion
# Processing Record 179 of Set 1 | kavieng
# Processing Record 180 of Set 1 | manggar
# Processing Record 181 of Set 1 | bilma
# Processing Record 182 of Set 1 | astoria
# Processing Record 183 of Set 1 | kjollefjord
# Processing Record 184 of Set 1 | plettenberg bay
# Processing Record 185 of Set 1 | hay river
# Processing Record 186 of Set 1 | puerto escondido
# Processing Record 187 of Set 1 | saldanha
# Processing Record 188 of Set 1 | havre-saint-pierre
# Processing Record 189 of Set 1 | dhidhdhoo
# Processing Record 190 of Set 1 | bodaybo
# Processing Record 191 of Set 1 | darhan
# Processing Record 192 of Set 1 | yorkton
# Processing Record 193 of Set 1 | narsaq
# Processing Record 194 of Set 1 | east london
# Processing Record 195 of Set 1 | kungurtug
# Processing Record 196 of Set 1 | saskylakh
# Processing Record 197 of Set 1 | henties bay
# Processing Record 198 of Set 1 | vilyuysk
# Processing Record 199 of Set 1 | marsh harbour
# Processing Record 200 of Set 1 | portree
# Processing Record 201 of Set 1 | bata
# Processing Record 202 of Set 1 | westport
# Processing Record 203 of Set 1 | meulaboh
# Processing Record 204 of Set 1 | bathsheba
# Processing Record 205 of Set 1 | chichihualco
# Processing Record 206 of Set 1 | masterton
# Processing Record 207 of Set 1 | bubaque
# Processing Record 208 of Set 1 | vardo
# Processing Record 209 of Set 1 | kokstad
# Processing Record 210 of Set 1 | taoudenni
# City not found. Skipping...
# Processing Record 211 of Set 1 | aklavik
# City not found. Skipping...
# Processing Record 212 of Set 1 | egvekinot
# Processing Record 213 of Set 1 | lingyuan
# City not found. Skipping...
# Processing Record 214 of Set 1 | tuy hoa
# Processing Record 215 of Set 1 | palana
# Processing Record 216 of Set 1 | zhashkiv
# Processing Record 217 of Set 1 | mykolayivka
# Processing Record 218 of Set 1 | bireun
# Processing Record 219 of Set 1 | alofi
# Processing Record 220 of Set 1 | kapaa
# Processing Record 221 of Set 1 | price
# Processing Record 222 of Set 1 | challapata
# Processing Record 223 of Set 1 | mehamn
# Processing Record 224 of Set 1 | nakhon phanom
# Processing Record 225 of Set 1 | margate
# Processing Record 226 of Set 1 | palmer
# Processing Record 227 of Set 1 | aksu
# Processing Record 228 of Set 1 | vieques
# Processing Record 229 of Set 1 | ukiah
# Processing Record 230 of Set 1 | isangel
# Processing Record 231 of Set 1 | tevriz
# Processing Record 232 of Set 1 | chernyshevskiy
# Processing Record 233 of Set 1 | tynda
# Processing Record 234 of Set 1 | pangai
# Processing Record 235 of Set 1 | hervey bay
# Processing Record 236 of Set 1 | nome
# Processing Record 237 of Set 1 | avera
# Processing Record 238 of Set 1 | vojens
# Processing Record 239 of Set 1 | haines junction
# Processing Record 240 of Set 1 | thaton
# City not found. Skipping...
# Processing Record 241 of Set 1 | college
# Processing Record 242 of Set 1 | kalmunai
# City not found. Skipping...
# Processing Record 243 of Set 1 | klaksvik
# Processing Record 244 of Set 1 | jizan
# Processing Record 245 of Set 1 | saint-francois
# Processing Record 246 of Set 1 | husavik
# Processing Record 247 of Set 1 | namibe
# Processing Record 248 of Set 1 | loiza
# Processing Record 249 of Set 1 | sault sainte marie
# Processing Record 250 of Set 1 | cozumel
# Processing Record 251 of Set 1 | half moon bay
# Processing Record 252 of Set 1 | olavarria
# Processing Record 253 of Set 1 | hami
# Processing Record 254 of Set 1 | lasa
# Processing Record 255 of Set 1 | komsomolskiy
# Processing Record 256 of Set 1 | touros
# Processing Record 257 of Set 1 | geraldton
# Processing Record 258 of Set 1 | sukhumi
# Processing Record 259 of Set 1 | bintulu
# Processing Record 260 of Set 1 | kendari
# Processing Record 261 of Set 1 | tuatapere
# Processing Record 262 of Set 1 | seoul
# City not found. Skipping...
# Processing Record 263 of Set 1 | skarnes
# Processing Record 264 of Set 1 | axim
# Processing Record 265 of Set 1 | srednekolymsk
# Processing Record 266 of Set 1 | mosquera
# Processing Record 267 of Set 1 | lamu
# Processing Record 268 of Set 1 | biak
# City not found. Skipping...
# Processing Record 269 of Set 1 | rokytne
# Processing Record 270 of Set 1 | marquette
# City not found. Skipping...
# Processing Record 271 of Set 1 | hualmay
# Processing Record 272 of Set 1 | nagato
# Processing Record 273 of Set 1 | mamallapuram
# Processing Record 274 of Set 1 | nabire
# Processing Record 275 of Set 1 | yagodnoye
# Processing Record 276 of Set 1 | sosnovoborsk
# Processing Record 277 of Set 1 | tambopata
# Processing Record 278 of Set 1 | sapucaia
# Processing Record 279 of Set 1 | sao filipe
# Processing Record 280 of Set 1 | coihaique
# Processing Record 281 of Set 1 | san patricio
# Processing Record 282 of Set 1 | pontianak
# Processing Record 283 of Set 1 | ongandjera
# Processing Record 284 of Set 1 | port blair
# Processing Record 285 of Set 1 | lorengau
# Processing Record 286 of Set 1 | vila franca do campo
# Processing Record 287 of Set 1 | ketchikan
# Processing Record 288 of Set 1 | hambantota
# Processing Record 289 of Set 1 | arlit
# Processing Record 290 of Set 1 | marawi
# Processing Record 291 of Set 1 | arroyo
# Processing Record 292 of Set 1 | langenlois
# Processing Record 293 of Set 1 | mahajanga
# Processing Record 294 of Set 1 | kruisfontein
# Processing Record 295 of Set 1 | severo-kurilsk
# Processing Record 296 of Set 1 | faya
# City not found. Skipping...
# Processing Record 297 of Set 1 | nizwa
# Processing Record 298 of Set 1 | diffa
# Processing Record 299 of Set 1 | laguna
# Processing Record 300 of Set 1 | asosa
# Processing Record 301 of Set 1 | deori khas
# Processing Record 302 of Set 1 | altos
# Processing Record 303 of Set 1 | surt
# Processing Record 304 of Set 1 | brae
# Processing Record 305 of Set 1 | grootfontein
# City not found. Skipping...
# Processing Record 306 of Set 1 | terrak
# Processing Record 307 of Set 1 | gondar
# Processing Record 308 of Set 1 | lagoa
# Processing Record 309 of Set 1 | vestmannaeyjar
# Processing Record 310 of Set 1 | khatanga
# Processing Record 311 of Set 1 | darnah
# Processing Record 312 of Set 1 | den helder
# Processing Record 313 of Set 1 | tlacotepec
# Processing Record 314 of Set 1 | tocopilla
# Processing Record 315 of Set 1 | bairiki
# Processing Record 316 of Set 1 | sri aman
# Processing Record 317 of Set 1 | lodja
# Processing Record 318 of Set 1 | mitsamiouli
# Processing Record 319 of Set 1 | rameswaram
# Processing Record 320 of Set 1 | rabo de peixe
# Processing Record 321 of Set 1 | rocha
# Processing Record 322 of Set 1 | maarianhamina
# Processing Record 323 of Set 1 | redcliffe
# Processing Record 324 of Set 1 | parabel
# Processing Record 325 of Set 1 | kayanza
# Processing Record 326 of Set 1 | bonavista
# Processing Record 327 of Set 1 | ancud
# Processing Record 328 of Set 1 | garowe
# Processing Record 329 of Set 1 | veraval
# Processing Record 330 of Set 1 | mangochi
# Processing Record 331 of Set 1 | niquelandia
# Processing Record 332 of Set 1 | stornoway
# Processing Record 333 of Set 1 | faridabad
# Processing Record 334 of Set 1 | birao
# Processing Record 335 of Set 1 | guiglo
# Processing Record 336 of Set 1 | dawlatabad
# Processing Record 337 of Set 1 | tautira
# Processing Record 338 of Set 1 | zhigansk
# Processing Record 339 of Set 1 | naze
# Processing Record 340 of Set 1 | alice springs
# City not found. Skipping...
# Processing Record 341 of Set 1 | tucurui
# Processing Record 342 of Set 1 | marzuq
# Processing Record 343 of Set 1 | santa cruz del sur
# Processing Record 344 of Set 1 | looc
# Processing Record 345 of Set 1 | kuvshinovo
# Processing Record 346 of Set 1 | coahuayana
# Processing Record 347 of Set 1 | mangaluru
# Processing Record 348 of Set 1 | miguel hidalgo
# Processing Record 349 of Set 1 | nizhniye vyazovyye
# Processing Record 350 of Set 1 | lubumbashi
# Processing Record 351 of Set 1 | mwinilunga
# Processing Record 352 of Set 1 | mocuba
# Processing Record 353 of Set 1 | grand-santi
# Processing Record 354 of Set 1 | bodden town
# Processing Record 355 of Set 1 | luganville
# Processing Record 356 of Set 1 | oranjemund
# Processing Record 357 of Set 1 | nouadhibou
# Processing Record 358 of Set 1 | oktyabrskoye
# Processing Record 359 of Set 1 | serenje
# Processing Record 360 of Set 1 | utete
# Processing Record 361 of Set 1 | nizhneangarsk
# Processing Record 362 of Set 1 | licata
# Processing Record 363 of Set 1 | dingle
# Processing Record 364 of Set 1 | portland
# Processing Record 365 of Set 1 | zarubino
# City not found. Skipping...
# Processing Record 366 of Set 1 | tura
# Processing Record 367 of Set 1 | ploemeur
# City not found. Skipping...
# Processing Record 368 of Set 1 | shenjiamen
# Processing Record 369 of Set 1 | sao joao da barra
# Processing Record 370 of Set 1 | luwuk
# Processing Record 371 of Set 1 | merauke
# Processing Record 372 of Set 1 | puerto ayacucho
# Processing Record 373 of Set 1 | vostok
# Processing Record 374 of Set 1 | uusikaupunki
# Processing Record 375 of Set 1 | pisco
# Processing Record 376 of Set 1 | guerrero negro
# Processing Record 377 of Set 1 | kosh-agach
# Processing Record 378 of Set 1 | mastic beach
# Processing Record 379 of Set 1 | mahebourg
# Processing Record 380 of Set 1 | sept-iles
# Processing Record 381 of Set 1 | abu samrah
# Processing Record 382 of Set 1 | yerbogachen
# Processing Record 383 of Set 1 | ossora
# Processing Record 384 of Set 1 | pushkar
# Processing Record 385 of Set 1 | ngaoundere
# Processing Record 386 of Set 1 | fairbanks
# Processing Record 387 of Set 1 | slidell
# Processing Record 388 of Set 1 | surab
# Processing Record 389 of Set 1 | monrovia
# Processing Record 390 of Set 1 | atherton
# Processing Record 391 of Set 1 | maihar
# Processing Record 392 of Set 1 | pimentel
# Processing Record 393 of Set 1 | dandong
# Processing Record 394 of Set 1 | tilichiki
# City not found. Skipping...
# Processing Record 395 of Set 1 | nangka
# Processing Record 396 of Set 1 | nassau
# Processing Record 397 of Set 1 | san carlos de bariloche
# Processing Record 398 of Set 1 | seddon
# Processing Record 399 of Set 1 | karratha
# City not found. Skipping...
# Processing Record 400 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 401 of Set 1 | seymchan
# Processing Record 402 of Set 1 | lazaro cardenas
# Processing Record 403 of Set 1 | ilo
# Processing Record 404 of Set 1 | verkh-chebula
# Processing Record 405 of Set 1 | tiznit
# Processing Record 406 of Set 1 | la paz
# Processing Record 407 of Set 1 | riachao das neves
# Processing Record 408 of Set 1 | waipawa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 409 of Set 1 | necochea
# Processing Record 410 of Set 1 | carbonia
# Processing Record 411 of Set 1 | bud
# Processing Record 412 of Set 1 | nata
# Processing Record 413 of Set 1 | fianarantsoa
# Processing Record 414 of Set 1 | mogadishu
# Processing Record 415 of Set 1 | poronaysk
# Processing Record 416 of Set 1 | awbari
# Processing Record 417 of Set 1 | unity
# Processing Record 418 of Set 1 | chuy
# Processing Record 419 of Set 1 | dogondoutchi
# Processing Record 420 of Set 1 | lodwar
# Processing Record 421 of Set 1 | cartagena
# Processing Record 422 of Set 1 | grand baie
# Processing Record 423 of Set 1 | ca mau
# Processing Record 424 of Set 1 | ostrovnoy
# Processing Record 425 of Set 1 | cairns
# Processing Record 426 of Set 1 | batagay-alyta
# Processing Record 427 of Set 1 | ponerihouen
# Processing Record 428 of Set 1 | ukwa
# Processing Record 429 of Set 1 | andenes
# Processing Record 430 of Set 1 | basco
# Processing Record 431 of Set 1 | cascais
# Processing Record 432 of Set 1 | raudeberg
# Processing Record 433 of Set 1 | kalengwa
# Processing Record 434 of Set 1 | charyshskoye
# Processing Record 435 of Set 1 | varnamo
# City not found. Skipping...
# Processing Record 436 of Set 1 | bunol
# Processing Record 437 of Set 1 | uttarkashi
# Processing Record 438 of Set 1 | dzhebariki-khaya
# Processing Record 439 of Set 1 | sungairaya
# Processing Record 440 of Set 1 | bluefield
# Processing Record 441 of Set 1 | sabha
# Processing Record 442 of Set 1 | yemtsa
# Processing Record 443 of Set 1 | qiongshan
# Processing Record 444 of Set 1 | buala
# Processing Record 445 of Set 1 | sobolevo
# Processing Record 446 of Set 1 | talaya
# Processing Record 447 of Set 1 | virginia beach
# Processing Record 448 of Set 1 | belyy yar
# Processing Record 449 of Set 1 | murbad
# Processing Record 450 of Set 1 | inongo
# Processing Record 451 of Set 1 | broken hill
# Processing Record 452 of Set 1 | vao
# Processing Record 453 of Set 1 | bayir
# City not found. Skipping...
# Processing Record 454 of Set 1 | kintinku
# Processing Record 455 of Set 1 | beyneu
# Processing Record 456 of Set 1 | timra
# Processing Record 457 of Set 1 | sayyan
# Processing Record 458 of Set 1 | benoy
# Processing Record 459 of Set 1 | souillac
# Processing Record 460 of Set 1 | akure
# Processing Record 461 of Set 1 | concepcion del oro
# Processing Record 462 of Set 1 | strezhevoy
# Processing Record 463 of Set 1 | carutapera
# Processing Record 464 of Set 1 | bukachacha
# City not found. Skipping...
# Processing Record 465 of Set 1 | dickinson
# Processing Record 466 of Set 1 | kasungu
# Processing Record 467 of Set 1 | dajal
# Processing Record 468 of Set 1 | finote selam
# Processing Record 469 of Set 1 | natal
# City not found. Skipping...
# Processing Record 470 of Set 1 | amsterdam
# Processing Record 471 of Set 1 | hashtrud
# Processing Record 472 of Set 1 | zeya
# Processing Record 473 of Set 1 | viedma
# Processing Record 474 of Set 1 | la rioja
# Processing Record 475 of Set 1 | ust-nera
# Processing Record 476 of Set 1 | te anau
# Processing Record 477 of Set 1 | sassandra
# Processing Record 478 of Set 1 | tacuarembo
# Processing Record 479 of Set 1 | mariara
# Processing Record 480 of Set 1 | cabedelo
# Processing Record 481 of Set 1 | grand gaube
# Processing Record 482 of Set 1 | murdochville
# Processing Record 483 of Set 1 | ternate
# Processing Record 484 of Set 1 | sesheke
# Processing Record 485 of Set 1 | booue
# Processing Record 486 of Set 1 | kang
# Processing Record 487 of Set 1 | mana
# Processing Record 488 of Set 1 | chorozinho
# Processing Record 489 of Set 1 | lajas
# Processing Record 490 of Set 1 | anjangaon
# Processing Record 491 of Set 1 | ligayan
# City not found. Skipping...
# Processing Record 492 of Set 1 | eureka
# Processing Record 493 of Set 1 | valdepenas
# Processing Record 494 of Set 1 | dukat
# Processing Record 495 of Set 1 | hohhot
# Processing Record 496 of Set 1 | vanimo
# Processing Record 497 of Set 1 | juegang
# Processing Record 498 of Set 1 | taltal
# Processing Record 499 of Set 1 | morehead
# Processing Record 500 of Set 1 | kenai
# Processing Record 501 of Set 1 | port augusta
# Processing Record 502 of Set 1 | sterling
# Processing Record 503 of Set 1 | wucheng
# Processing Record 504 of Set 1 | bengkulu
# Processing Record 505 of Set 1 | kahului
# Processing Record 506 of Set 1 | joao pinheiro
# Processing Record 507 of Set 1 | taga
# Processing Record 508 of Set 1 | santa maria do suacui
# Processing Record 509 of Set 1 | lahij
# Processing Record 510 of Set 1 | gazli
# Processing Record 511 of Set 1 | adrar
# Processing Record 512 of Set 1 | paso de los toros
# Processing Record 513 of Set 1 | cidreira
# Processing Record 514 of Set 1 | simao
# Processing Record 515 of Set 1 | damghan
# Processing Record 516 of Set 1 | sanbu
# Processing Record 517 of Set 1 | cuamba
# Processing Record 518 of Set 1 | catamarca
# Processing Record 519 of Set 1 | maceio
# City not found. Skipping...
# Processing Record 520 of Set 1 | wuwei
# Processing Record 521 of Set 1 | kidal
# Processing Record 522 of Set 1 | solwezi
# Processing Record 523 of Set 1 | chivay
# Processing Record 524 of Set 1 | bambanglipuro
# Processing Record 525 of Set 1 | nador
# Processing Record 526 of Set 1 | hadejia
# Processing Record 527 of Set 1 | singkawang
# Processing Record 528 of Set 1 | ponnani
# Processing Record 529 of Set 1 | jinchang
# Processing Record 530 of Set 1 | rio grande
# Processing Record 531 of Set 1 | belaya gora
# Processing Record 532 of Set 1 | matara
# Processing Record 533 of Set 1 | grindavik
# Processing Record 534 of Set 1 | krasnomayskiy
# Processing Record 535 of Set 1 | tazovskiy
# Processing Record 536 of Set 1 | upata
# Processing Record 537 of Set 1 | kangaatsiaq
# Processing Record 538 of Set 1 | sisimiut
# Processing Record 539 of Set 1 | busdi
# Processing Record 540 of Set 1 | cap malheureux
# Processing Record 541 of Set 1 | ginda
# Processing Record 542 of Set 1 | porto novo
# Processing Record 543 of Set 1 | banes
# Processing Record 544 of Set 1 | pandan
# Processing Record 545 of Set 1 | noyabrsk
# Processing Record 546 of Set 1 | blagoyevo
# Processing Record 547 of Set 1 | panguna
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 548 of Set 1 | epernay
# Processing Record 549 of Set 1 | davenda
# Processing Record 550 of Set 1 | turangi
# Processing Record 551 of Set 1 | puebloviejo
# Processing Record 552 of Set 1 | richards bay
# Processing Record 553 of Set 1 | shenkursk
# City not found. Skipping...
# Processing Record 554 of Set 1 | kenora
# Processing Record 555 of Set 1 | nara
# Processing Record 556 of Set 1 | mareeba
# Processing Record 557 of Set 1 | bendigo
# Processing Record 558 of Set 1 | puri
# Processing Record 559 of Set 1 | manaquiri
# Processing Record 560 of Set 1 | along
# City not found. Skipping...
# Processing Record 561 of Set 1 | vanavara
# Processing Record 562 of Set 1 | sao jose do belmonte
# Processing Record 563 of Set 1 | pokhara
# Processing Record 564 of Set 1 | varhaug
# Processing Record 565 of Set 1 | minbu
# City not found. Skipping...
# Processing Record 566 of Set 1 | namatanai
# -----------------------------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame from lists defined above

weather_dictionary = {"Name": name_city,
                      "Clouds": cloudiness,
                      "Country": country,
                      "Date": date,
                      "Humidity": humidity,
                      "Lat": latitude,
                      "Lng": longitude,
                      "Max Temp": max_temp,
                      "Wind Speed": wind_speed}

weather_data = pd.DataFrame(weather_dictionary)
weather_data.to_csv("weather_output.csv")
weather_data
# Out:
#                      Name  Clouds Country        Date  Humidity    Lat  \
# 0               Bulalacao       8      PH  1584230865        80  12.33
# 1                 Ahipara       0      NZ  1584230867        68 -35.17
# 2              Codrington      47      AU  1584230869        71 -38.27
# 3           Cockburn Town       0      TC  1584230787        78  21.46
# 4                Cam Ranh      40      VN  1584230875        88  11.92
# ..                    ...     ...     ...         ...       ...    ...
# 562  São José do Belmonte      99      BR  1584232235        59  -7.86
# 563               Pokhara      98      NP  1584232237        85  28.23
# 564               Varhaug      90      NO  1584232239        93  58.61
# 565                 Minbu      26      MM  1584232241        49  20.18
# 566             Namatanai     100      PG  1584232037        75  -3.67
#
#         Lng  Max Temp  Wind Speed
# 0    121.34    298.90        5.02
# 1    173.17    292.52        3.83
# 2    141.97    288.15        6.79
# 3    -71.14    297.80        8.99
# 4    109.16    300.15        3.10
# ..      ...       ...         ...
# 562  -38.76    299.29        5.05
# 563   83.98    285.08        0.97
# 564    5.65    279.82       11.30
# 565   94.88    295.71        1.71
# 566  152.43    301.58        4.90
#
# [567 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
