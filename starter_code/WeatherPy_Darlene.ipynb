# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
query_url = f"{base_url}appid={weather_api_key}&q="

# Initiate Count
record_number = 0

# Set up lists to hold reponse info in dataframe
name_city = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

# Print Header
print(f"Beginning Data Retrieval")
print(f"-----------------------------------------")

# Loop through the list of cities
for city in cities:    
    
    # Create search query, make request and store in json with a 2 second timer for pausing to avoid temporarily blocking my OpenWeatherMap API key
    weather_response = requests.get(query_url + str(city))
    weather_response_json = weather_response.json()
    time.sleep(2)   
    
    # Try to retrieve and store weather conditions into lists and if a random city is not found in the Open Weathermap then skip 
    try:
        name_city.append(weather_response_json["name"])
        cloudiness.append(weather_response_json["clouds"]["all"])
        country.append(weather_response_json["sys"]["country"])
        date.append(weather_response_json["dt"])
        humidity.append(weather_response_json["main"]["humidity"])
        latitude.append(weather_response_json["coord"]["lat"])
        longitude.append(weather_response_json["coord"]["lon"])
        
        # Convert Max Temp from Kelvin to Fahrenheit
        fahrenheit = (weather_response_json["main"]["temp_max"]-273.15) * 9/5 + 32
        max_temp.append(fahrenheit)
        
        # Convert Wind Speed from Meters per Second to Miles per Hour
        mph = (weather_response_json["wind"]["speed"]) * 2.23694
        wind_speed.append(mph)
                   
        print(f"Processing Record {record_number} | {city}")
        record_number += 1
        #print(f"Processing Record {record_number}")
        
    except:
        # Append null values
        print("City not found. Skipping...")

print(f"-----------------------------------------")
print(f"Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -----------------------------------------
# Processing Record 0 | hilo
# City not found. Skipping...
# Processing Record 1 | avarua
# Processing Record 2 | xiongzhou
# Processing Record 3 | rikitea
# Processing Record 4 | hermanus
# Processing Record 5 | kapaa
# Processing Record 6 | cockburn town
# Processing Record 7 | yulara
# Processing Record 8 | ransang
# Processing Record 9 | huambo
# Processing Record 10 | peace river
# Processing Record 11 | pisco
# Processing Record 12 | mataura
# Processing Record 13 | deer lake
# Processing Record 14 | korla
# Processing Record 15 | ushuaia
# Processing Record 16 | krasnoborsk
# Processing Record 17 | yellowknife
# City not found. Skipping...
# Processing Record 18 | east london
# City not found. Skipping...
# Processing Record 19 | albany
# Processing Record 20 | wajir
# Processing Record 21 | hithadhoo
# Processing Record 22 | noumea
# Processing Record 23 | russell
# City not found. Skipping...
# Processing Record 24 | cape town
# Processing Record 25 | nelson bay
# Processing Record 26 | irtyshskiy
# Processing Record 27 | mwingi
# Processing Record 28 | tomakomai
# Processing Record 29 | kodiak
# Processing Record 30 | andenes
# Processing Record 31 | barrow
# Processing Record 32 | lebu
# Processing Record 33 | hobart
# Processing Record 34 | vestmanna
# Processing Record 35 | bluff
# Processing Record 36 | mar del plata
# Processing Record 37 | varkkallai
# Processing Record 38 | alofi
# Processing Record 39 | saint-philippe
# Processing Record 40 | new norfolk
# Processing Record 41 | qaanaaq
# Processing Record 42 | bundaberg
# Processing Record 43 | bintulu
# Processing Record 44 | amga
# Processing Record 45 | cranbrook
# Processing Record 46 | sorong
# Processing Record 47 | lons-le-saunier
# Processing Record 48 | portland
# Processing Record 49 | atuona
# Processing Record 50 | port hardy
# Processing Record 51 | vaini
# Processing Record 52 | huarmey
# Processing Record 53 | namwala
# Processing Record 54 | esperance
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 55 | kaitangata
# Processing Record 56 | nouadhibou
# Processing Record 57 | clyde river
# City not found. Skipping...
# Processing Record 58 | belmopan
# Processing Record 59 | yendi
# Processing Record 60 | tuatapere
# Processing Record 61 | nanortalik
# Processing Record 62 | ilulissat
# Processing Record 63 | punta arenas
# Processing Record 64 | port hedland
# Processing Record 65 | wuzhou
# Processing Record 66 | paka
# Processing Record 67 | ribeira grande
# Processing Record 68 | atasu
# Processing Record 69 | thompson
# Processing Record 70 | yangambi
# Processing Record 71 | mount isa
# Processing Record 72 | jan kempdorp
# Processing Record 73 | san patricio
# Processing Record 74 | norman wells
# Processing Record 75 | tabou
# Processing Record 76 | kavieng
# Processing Record 77 | cayenne
# Processing Record 78 | torbay
# Processing Record 79 | katsuura
# Processing Record 80 | fare
# Processing Record 81 | saskylakh
# Processing Record 82 | havoysund
# Processing Record 83 | busselton
# Processing Record 84 | tiksi
# Processing Record 85 | temerloh
# Processing Record 86 | bredasdorp
# Processing Record 87 | gazimurskiy zavod
# Processing Record 88 | shimoda
# Processing Record 89 | peta
# Processing Record 90 | shirokiy
# Processing Record 91 | victoria
# Processing Record 92 | san vicente
# Processing Record 93 | aleksandrov gay
# Processing Record 94 | cascais
# Processing Record 95 | carnarvon
# Processing Record 96 | dwarka
# Processing Record 97 | moron
# Processing Record 98 | teya
# Processing Record 99 | tuktoyaktuk
# Processing Record 100 | sao gabriel da cachoeira
# Processing Record 101 | moose factory
# Processing Record 102 | brae
# Processing Record 103 | cherskiy
# Processing Record 104 | dikson
# Processing Record 105 | bambous virieux
# Processing Record 106 | hervey bay
# Processing Record 107 | sirsa
# City not found. Skipping...
# Processing Record 108 | butaritari
# Processing Record 109 | poum
# Processing Record 110 | tulum
# Processing Record 111 | kamareddi
# Processing Record 112 | presidencia roque saenz pena
# Processing Record 113 | egvekinot
# Processing Record 114 | cidreira
# Processing Record 115 | antofagasta
# Processing Record 116 | kozhva
# Processing Record 117 | saint george
# Processing Record 118 | canutama
# Processing Record 119 | tchibanga
# Processing Record 120 | oud-beijerland
# Processing Record 121 | alice springs
# Processing Record 122 | tilichiki
# Processing Record 123 | nome
# Processing Record 124 | bukama
# Processing Record 125 | port elizabeth
# Processing Record 126 | codrington
# Processing Record 127 | labrea
# Processing Record 128 | raton
# City not found. Skipping...
# Processing Record 129 | semey
# Processing Record 130 | atar
# Processing Record 131 | mao
# Processing Record 132 | ola
# Processing Record 133 | dzhebariki-khaya
# Processing Record 134 | bethel
# Processing Record 135 | gaoua
# Processing Record 136 | dano
# Processing Record 137 | jalu
# City not found. Skipping...
# Processing Record 138 | suntar
# Processing Record 139 | provideniya
# Processing Record 140 | leshukonskoye
# Processing Record 141 | camacha
# Processing Record 142 | atbasar
# Processing Record 143 | souillac
# Processing Record 144 | eureka
# Processing Record 145 | khatanga
# Processing Record 146 | hovd
# Processing Record 147 | tashtyp
# Processing Record 148 | pierre
# Processing Record 149 | fortuna
# Processing Record 150 | taltal
# Processing Record 151 | adrar
# Processing Record 152 | hasaki
# Processing Record 153 | bengkulu
# Processing Record 154 | aksakovo
# City not found. Skipping...
# Processing Record 155 | wiwili
# Processing Record 156 | price
# Processing Record 157 | ponta do sol
# Processing Record 158 | sikonge
# Processing Record 159 | tasiilaq
# Processing Record 160 | tupancireta
# Processing Record 161 | constitucion
# City not found. Skipping...
# Processing Record 162 | port alfred
# Processing Record 163 | kaohsiung
# Processing Record 164 | chuy
# Processing Record 165 | cabo san lucas
# Processing Record 166 | hambantota
# Processing Record 167 | narsaq
# Processing Record 168 | puerto ayora
# Processing Record 169 | jaque
# Processing Record 170 | jamestown
# Processing Record 171 | ostersund
# Processing Record 172 | tutoia
# Processing Record 173 | sao filipe
# Processing Record 174 | biltine
# Processing Record 175 | mashhad
# Processing Record 176 | banda aceh
# Processing Record 177 | ibate
# Processing Record 178 | mikumi
# Processing Record 179 | mutoko
# Processing Record 180 | husavik
# City not found. Skipping...
# Processing Record 181 | chandrakona
# Processing Record 182 | kosice
# Processing Record 183 | lubango
# Processing Record 184 | kupang
# Processing Record 185 | solok
# Processing Record 186 | tayshet
# Processing Record 187 | evensk
# Processing Record 188 | borba
# Processing Record 189 | flin flon
# Processing Record 190 | camocim
# Processing Record 191 | mahina
# Processing Record 192 | boyolangu
# Processing Record 193 | athabasca
# Processing Record 194 | kangaatsiaq
# Processing Record 195 | bonavista
# Processing Record 196 | guangshui
# Processing Record 197 | richards bay
# City not found. Skipping...
# Processing Record 198 | bosaso
# Processing Record 199 | kailua
# Processing Record 200 | arraial do cabo
# Processing Record 201 | oistins
# City not found. Skipping...
# Processing Record 202 | teguldet
# Processing Record 203 | hobyo
# City not found. Skipping...
# Processing Record 204 | klaksvik
# Processing Record 205 | marica
# Processing Record 206 | necochea
# Processing Record 207 | ahipara
# Processing Record 208 | kawhia
# Processing Record 209 | gat
# Processing Record 210 | salalah
# Processing Record 211 | buraydah
# Processing Record 212 | lavrentiya
# Processing Record 213 | georgetown
# Processing Record 214 | iqaluit
# Processing Record 215 | la paz
# Processing Record 216 | namatanai
# Processing Record 217 | rio grande
# Processing Record 218 | osoyoos
# City not found. Skipping...
# Processing Record 219 | charters towers
# Processing Record 220 | iberia
# Processing Record 221 | vakhrushi
# Processing Record 222 | green river
# Processing Record 223 | humaita
# Processing Record 224 | grindavik
# Processing Record 225 | alta floresta
# Processing Record 226 | sri aman
# Processing Record 227 | pangnirtung
# Processing Record 228 | urumqi
# Processing Record 229 | victoria point
# Processing Record 230 | castro
# Processing Record 231 | te anau
# City not found. Skipping...
# Processing Record 232 | popondetta
# Processing Record 233 | elat
# Processing Record 234 | mahebourg
# City not found. Skipping...
# Processing Record 235 | harper
# Processing Record 236 | nago
# Processing Record 237 | lensk
# City not found. Skipping...
# Processing Record 238 | pevek
# City not found. Skipping...
# Processing Record 239 | rawson
# Processing Record 240 | pontianak
# Processing Record 241 | roura
# Processing Record 242 | namibe
# Processing Record 243 | skjervoy
# Processing Record 244 | smithers
# Processing Record 245 | sakakah
# Processing Record 246 | faanui
# Processing Record 247 | vytegra
# Processing Record 248 | safranbolu
# City not found. Skipping...
# Processing Record 249 | muros
# Processing Record 250 | wad rawah
# Processing Record 251 | beni mazar
# Processing Record 252 | beloha
# City not found. Skipping...
# Processing Record 253 | kruisfontein
# Processing Record 254 | santa cruz
# Processing Record 255 | auki
# Processing Record 256 | rantepao
# Processing Record 257 | le vauclin
# Processing Record 258 | grand gaube
# Processing Record 259 | upernavik
# City not found. Skipping...
# Processing Record 260 | airai
# Processing Record 261 | kahului
# City not found. Skipping...
# Processing Record 262 | lakes entrance
# Processing Record 263 | nesterov
# Processing Record 264 | isangel
# Processing Record 265 | champerico
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 266 | sobolevo
# Processing Record 267 | saldanha
# Processing Record 268 | pecineaga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 269 | khanapur
# Processing Record 270 | makat
# Processing Record 271 | black river
# Processing Record 272 | aguimes
# Processing Record 273 | horsham
# Processing Record 274 | vagay
# Processing Record 275 | ambilobe
# Processing Record 276 | ouahigouya
# Processing Record 277 | ambositra
# Processing Record 278 | geraldton
# Processing Record 279 | severo-kurilsk
# City not found. Skipping...
# Processing Record 280 | merauke
# Processing Record 281 | chokurdakh
# Processing Record 282 | mayo
# Processing Record 283 | mitsamiouli
# Processing Record 284 | lasa
# City not found. Skipping...
# Processing Record 285 | sinnamary
# Processing Record 286 | goderich
# Processing Record 287 | talnakh
# Processing Record 288 | puri
# Processing Record 289 | viedma
# Processing Record 290 | mendi
# Processing Record 291 | kenora
# Processing Record 292 | san policarpo
# Processing Record 293 | mumford
# Processing Record 294 | estancia velha
# Processing Record 295 | santa cruz de la palma
# Processing Record 296 | inhuma
# Processing Record 297 | musoma
# Processing Record 298 | tautira
# Processing Record 299 | batsfjord
# Processing Record 300 | glendive
# Processing Record 301 | xining
# City not found. Skipping...
# Processing Record 302 | nieuw amsterdam
# Processing Record 303 | ogaminana
# Processing Record 304 | kempsey
# Processing Record 305 | waipawa
# City not found. Skipping...
# Processing Record 306 | havre
# Processing Record 307 | myitkyina
# Processing Record 308 | morristown
# Processing Record 309 | saint-augustin
# Processing Record 310 | leningradskiy
# Processing Record 311 | estelle
# Processing Record 312 | deep river
# Processing Record 313 | shakawe
# Processing Record 314 | raudeberg
# City not found. Skipping...
# Processing Record 315 | beatrice
# Processing Record 316 | koch bihar
# Processing Record 317 | soe
# Processing Record 318 | shivrajpur
# Processing Record 319 | bilibino
# Processing Record 320 | derzhavinsk
# Processing Record 321 | chapais
# City not found. Skipping...
# Processing Record 322 | gboko
# Processing Record 323 | kabalo
# City not found. Skipping...
# Processing Record 324 | harindanga
# Processing Record 325 | eyl
# Processing Record 326 | eyrarbakki
# Processing Record 327 | tazovskiy
# Processing Record 328 | hamilton
# Processing Record 329 | homer
# Processing Record 330 | lillooet
# Processing Record 331 | mecca
# Processing Record 332 | galesong
# Processing Record 333 | predivinsk
# Processing Record 334 | ouadda
# Processing Record 335 | plettenberg bay
# Processing Record 336 | olinda
# Processing Record 337 | koulamoutou
# Processing Record 338 | roald
# City not found. Skipping...
# Processing Record 339 | fairbanks
# Processing Record 340 | baoding
# Processing Record 341 | vanavara
# Processing Record 342 | fatezh
# Processing Record 343 | primorsk
# Processing Record 344 | vostok
# Processing Record 345 | kandrian
# Processing Record 346 | lorengau
# Processing Record 347 | mukhen
# Processing Record 348 | beaverlodge
# Processing Record 349 | kungurtug
# Processing Record 350 | faya
# Processing Record 351 | kaeo
# Processing Record 352 | ordzhonikidze
# Processing Record 353 | touros
# Processing Record 354 | jiuquan
# Processing Record 355 | belaya gora
# Processing Record 356 | kalaleh
# Processing Record 357 | bathsheba
# Processing Record 358 | ancud
# Processing Record 359 | sucua
# Processing Record 360 | vila velha
# Processing Record 361 | los llanos de aridane
# Processing Record 362 | naze
# Processing Record 363 | aklavik
# Processing Record 364 | boa vista
# Processing Record 365 | rach gia
# Processing Record 366 | sungaipenuh
# Processing Record 367 | hede
# Processing Record 368 | bima
# Processing Record 369 | whitehorse
# Processing Record 370 | kamenka
# City not found. Skipping...
# Processing Record 371 | arman
# Processing Record 372 | praya
# Processing Record 373 | kavaratti
# Processing Record 374 | bitam
# Processing Record 375 | port townsend
# Processing Record 376 | hudson bay
# Processing Record 377 | saint-francois
# Processing Record 378 | hami
# Processing Record 379 | severo-yeniseyskiy
# Processing Record 380 | yar-sale
# Processing Record 381 | cesme
# Processing Record 382 | salinopolis
# Processing Record 383 | markova
# City not found. Skipping...
# Processing Record 384 | nanchang
# Processing Record 385 | vestmannaeyjar
# Processing Record 386 | waw
# Processing Record 387 | thinadhoo
# Processing Record 388 | chenzhou
# Processing Record 389 | luderitz
# Processing Record 390 | nizwa
# Processing Record 391 | peleduy
# Processing Record 392 | tocopilla
# Processing Record 393 | coahuayana
# Processing Record 394 | ulladulla
# Processing Record 395 | peddapalli
# Processing Record 396 | hvide sande
# City not found. Skipping...
# Processing Record 397 | locri
# Processing Record 398 | maloy
# Processing Record 399 | vardo
# Processing Record 400 | magadan
# Processing Record 401 | nikolskoye
# City not found. Skipping...
# Processing Record 402 | hukuntsi
# Processing Record 403 | matinha
# Processing Record 404 | bambanglipuro
# Processing Record 405 | demba
# City not found. Skipping...
# Processing Record 406 | keta
# Processing Record 407 | cortez
# Processing Record 408 | padang
# City not found. Skipping...
# Processing Record 409 | aykhal
# Processing Record 410 | nishihara
# Processing Record 411 | omsukchan
# Processing Record 412 | lahij
# Processing Record 413 | nabire
# Processing Record 414 | surt
# Processing Record 415 | lutry
# Processing Record 416 | mehamn
# Processing Record 417 | port lincoln
# Processing Record 418 | ust-tsilma
# Processing Record 419 | turukhansk
# Processing Record 420 | sembakung
# Processing Record 421 | manaus
# Processing Record 422 | khanpur
# City not found. Skipping...
# Processing Record 423 | batagay
# Processing Record 424 | katobu
# Processing Record 425 | tulun
# Processing Record 426 | finschhafen
# Processing Record 427 | lompoc
# Processing Record 428 | tagusao
# Processing Record 429 | sept-iles
# Processing Record 430 | adalaj
# Processing Record 431 | gari
# Processing Record 432 | jaisalmer
# City not found. Skipping...
# Processing Record 433 | turan
# Processing Record 434 | ende
# Processing Record 435 | port macquarie
# Processing Record 436 | novomykolayivka
# Processing Record 437 | teguise
# City not found. Skipping...
# Processing Record 438 | taft
# Processing Record 439 | middelburg
# Processing Record 440 | margate
# Processing Record 441 | mizan teferi
# Processing Record 442 | westport
# Processing Record 443 | pinos
# Processing Record 444 | north platte
# Processing Record 445 | porto novo
# Processing Record 446 | beira
# City not found. Skipping...
# Processing Record 447 | saint-denis
# Processing Record 448 | sao jose da coroa grande
# Processing Record 449 | lagoa
# Processing Record 450 | koumac
# Processing Record 451 | sivaki
# Processing Record 452 | januaria
# Processing Record 453 | osinki
# Processing Record 454 | leopold
# Processing Record 455 | berlevag
# Processing Record 456 | asau
# Processing Record 457 | bagdarin
# Processing Record 458 | mae sai
# Processing Record 459 | abu kamal
# Processing Record 460 | ialibu
# City not found. Skipping...
# Processing Record 461 | jijiga
# Processing Record 462 | ilheus
# Processing Record 463 | jabinyanah
# Processing Record 464 | gresham
# Processing Record 465 | aswan
# Processing Record 466 | mozarlandia
# Processing Record 467 | hendek
# Processing Record 468 | ostrovnoy
# Processing Record 469 | mount gambier
# Processing Record 470 | oudtshoorn
# Processing Record 471 | sitka
# Processing Record 472 | obo
# Processing Record 473 | la asuncion
# Processing Record 474 | hualmay
# Processing Record 475 | socorro
# Processing Record 476 | bestobe
# Processing Record 477 | ketchikan
# Processing Record 478 | pervomayskiy
# Processing Record 479 | lokosovo
# Processing Record 480 | ambanja
# Processing Record 481 | vierzon
# Processing Record 482 | longyearbyen
# City not found. Skipping...
# Processing Record 483 | fort beaufort
# Processing Record 484 | vao
# Processing Record 485 | cap malheureux
# Processing Record 486 | praia da vitoria
# Processing Record 487 | bonfim
# City not found. Skipping...
# Processing Record 488 | saravena
# Processing Record 489 | seymchan
# Processing Record 490 | varkaus
# Processing Record 491 | ewo
# Processing Record 492 | mezen
# Processing Record 493 | fort nelson
# Processing Record 494 | mocuba
# Processing Record 495 | merced
# Processing Record 496 | rayong
# Processing Record 497 | hirara
# Processing Record 498 | kuldur
# Processing Record 499 | rocha
# Processing Record 500 | sao joao da barra
# Processing Record 501 | la union
# Processing Record 502 | larreynaga
# Processing Record 503 | isla mujeres
# Processing Record 504 | lumajang
# Processing Record 505 | sur
# Processing Record 506 | kirakira
# Processing Record 507 | abu dhabi
# Processing Record 508 | chemal
# Processing Record 509 | guerrero negro
# Processing Record 510 | san cristobal
# Processing Record 511 | dauphin
# Processing Record 512 | jiguani
# Processing Record 513 | gimli
# Processing Record 514 | saint-felicien
# Processing Record 515 | brovst
# Processing Record 516 | sarangani
# Processing Record 517 | coquimbo
# Processing Record 518 | sorland
# Processing Record 519 | port augusta
# Processing Record 520 | oranjemund
# Processing Record 521 | nemuro
# City not found. Skipping...
# Processing Record 522 | bubaque
# Processing Record 523 | carutapera
# Processing Record 524 | khandbari
# Processing Record 525 | maunabo
# Processing Record 526 | waiuku
# City not found. Skipping...
# Processing Record 527 | hofn
# Processing Record 528 | beroroha
# Processing Record 529 | manoharpur
# Processing Record 530 | kloulklubed
# Processing Record 531 | karratha
# Processing Record 532 | palmer
# Processing Record 533 | honningsvag
# Processing Record 534 | storforshei
# Processing Record 535 | lanigan
# Processing Record 536 | vavatenina
# Processing Record 537 | maceio
# Processing Record 538 | la ronge
# Processing Record 539 | kununurra
# Processing Record 540 | damavand
# City not found. Skipping...
# Processing Record 541 | normandin
# Processing Record 542 | zapolyarnyy
# Processing Record 543 | kalmunai
# Processing Record 544 | sakaiminato
# Processing Record 545 | tarnow
# Processing Record 546 | meulaboh
# Processing Record 547 | general pico
# Processing Record 548 | west odessa
# Processing Record 549 | gizo
# Processing Record 550 | knysna
# Processing Record 551 | terrace bay
# Processing Record 552 | cam ranh
# -----------------------------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame from lists defined above

weather_dictionary = {"Name": name_city,
                      "Clouds": cloudiness,
                      "Country": country,
                      "Date": date,
                      "Humidity": humidity,
                      "Lat": latitude,
                      "Lng": longitude,
                      "Max Temp": max_temp,
                      "Wind Speed": wind_speed}

weather_data = pd.DataFrame(weather_dictionary)
weather_data.to_csv("weather_data_output.csv")
weather_data
# Out:
#                         Name  Clouds Country        Date  Humidity    Lat  \
# 0                       Hilo       1      US  1584273579        83  19.73
# 1                     Avarua      51      CK  1584273583       100 -21.21
# 2                  Xiongzhou      26      CN  1584273356        56  25.12
# 3                    Rikitea       0      PF  1584273587        71 -23.12
# 4                   Hermanus      26      ZA  1584273589        90 -34.42
# ..                       ...     ...     ...         ...       ...    ...
# 548              West Odessa      90      US  1584274867       100  31.84
# 549  Gizo Government Station     100      SB  1584274869        83  -8.10
# 550                   Knysna      90      ZA  1584274871        88 -34.04
# 551              Terrace Bay      43      CA  1584274873        91  48.78
# 552                 Cam Ranh      20      VN  1584274875        88  11.92
#
#         Lng  Max Temp  Wind Speed
# 0   -155.09    71.600    4.697574
# 1   -159.78    75.200    2.236940
# 2    114.30    60.386    2.102724
# 3   -134.97    77.846    5.927891
# 4     19.23    71.996    8.008245
# ..      ...       ...         ...
# 548 -102.50    57.002   13.869028
# 549  156.84    78.746    2.885653
# 550   23.05    66.200   10.289924
# 551  -87.10    -5.674    3.959384
# 552  109.16    82.400   17.224438
#
# [553 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
